# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('/content/drive/MyDrive/MiningProcess_Flotation_Plant_Database.csv')

# %%
df.sample(10)
# Out:
#                        date % Iron Feed % Silica Feed     Starch Flow  \
# 696601  2017-08-31 13:00:00        54,4         18,52         5282,23
# 79356   2017-04-10 15:00:00       57,37         13,06         2072,47
# 278359  2017-05-26 17:00:00       64,03          6,26            3118
# 421534  2017-06-28 20:00:00        50,7         23,17         3450,87
# 91810   2017-04-13 13:00:00        55,6         13,79  407,2186086957
# 430171  2017-06-30 20:00:00       49,36         25,87          4589,4
# 278176  2017-05-26 16:00:00       64,03          6,26         3174,08
# 260061  2017-05-22 11:00:00       64,03          6,26         3333,41
# 408994  2017-06-25 23:00:00        60,4          8,69         3378,04
# 727237  2017-09-07 15:00:00        56,7         11,65         4011,47
#
#        Amina Flow   Ore Pulp Flow Ore Pulp pH Ore Pulp Density  \
# 696601    376,011  378,1074507772     9,43741          1,67035
# 79356     559,959         393,967      9,6348          1,76966
# ...

# %%
df.drop('date',axis=1,inplace=True)

# %%
df.sample(10)
# Out:
#        % Iron Feed % Silica Feed Starch Flow Amina Flow   Ore Pulp Flow  \
# 259381       64,03          6,26     3637,24    568,415         394,588
# 378665       48,82         22,32     3980,01     571,01         401,713
# 217270       52,61         20,24     3740,46    455,609         394,918
# 449744        50,7         22,76     3086,34     592,49         405,798
# 156357       53,54         18,74     2102,16    548,663         402,091
# 221052       64,03          6,26     599,731    502,215         400,586
# 75550        56,39         13,53     2143,82    398,898         400,628
# 421844        50,7         23,17     3724,65     583,81         403,467
# 283606       64,03          6,26     3253,91    447,388          398,73
# 511411        46,4         28,92     5044,86     429,53  404,1581232877
#
#        Ore Pulp pH Ore Pulp Density Flotation Column 01 Air Flow  \
# 259381     9,88574           1,6842                      298,556
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737453 entries, 0 to 737452
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   % Iron Feed                   737453 non-null  object
#  1   % Silica Feed                 737453 non-null  object
#  2   Starch Flow                   737453 non-null  object
#  3   Amina Flow                    737453 non-null  object
#  4   Ore Pulp Flow                 737453 non-null  object
#  5   Ore Pulp pH                   737453 non-null  object
#  6   Ore Pulp Density              737453 non-null  object
#  7   Flotation Column 01 Air Flow  737453 non-null  object
#  8   Flotation Column 02 Air Flow  737453 non-null  object
#  9   Flotation Column 03 Air Flow  737453 non-null  object
#  10  Flotation Column 04 Air Flow  737453 non-null  object
#  11  Flotation Column 05 Air Flow  737453 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# % Iron Feed                     0
# % Silica Feed                   0
# Starch Flow                     0
# Amina Flow                      0
# Ore Pulp Flow                   0
# Ore Pulp pH                     0
# Ore Pulp Density                0
# Flotation Column 01 Air Flow    0
# Flotation Column 02 Air Flow    0
# Flotation Column 03 Air Flow    0
# Flotation Column 04 Air Flow    0
# Flotation Column 05 Air Flow    0
# Flotation Column 06 Air Flow    0
# Flotation Column 07 Air Flow    0
# Flotation Column 01 Level       0
# Flotation Column 02 Level       0
# Flotation Column 03 Level       0
# Flotation Column 04 Level       0
# Flotation Column 05 Level       0
# Flotation Column 06 Level       0
# Flotation Column 07 Level       0
# % Iron Concentrate              0
# % Silica Concentrate            0
# dtype: int64

# %%
df.duplicated().any()
# Out:
# True

# %%
df.duplicated().sum()
# Out:
# 1171

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().any()
# Out:
# False

# %%
for i in df.columns:
  df[i]=df[i].str.replace(',','.')

# %%
df.sample(10)
# Out:
#        % Iron Feed % Silica Feed      Starch Flow      Amina Flow  \
# 570439       57.46          10.8  1418.6824754098  327.1337239884
# 123635       50.22          23.8        171.33248         532.837
# 18121        59.16         10.69           2391.8          436.34
# 276879       64.03          6.26          3290.07         495.663
# 8315         59.66          9.09          3592.19         550.171
# 473057       55.51         15.83          4654.34          607.89
# 663723        57.8         10.71          2503.29         466.263
# 45453        60.23          8.51          2009.44          562.14
# 344908       64.03          6.26          4222.43         476.577
# 680687       55.73         12.53          2971.17          425.82
#
#          Ore Pulp Flow Ore Pulp pH Ore Pulp Density  \
# 570439  377.8402461832     10.0625     1.5873003704
# 123635         396.244     9.66318          1.72615
# 18121          398.789     9.56238             1.75
# ...

# %%
df.dtypes
# Out:
# % Iron Feed                     object
# % Silica Feed                   object
# Starch Flow                     object
# Amina Flow                      object
# Ore Pulp Flow                   object
# Ore Pulp pH                     object
# Ore Pulp Density                object
# Flotation Column 01 Air Flow    object
# Flotation Column 02 Air Flow    object
# Flotation Column 03 Air Flow    object
# Flotation Column 04 Air Flow    object
# Flotation Column 05 Air Flow    object
# Flotation Column 06 Air Flow    object
# Flotation Column 07 Air Flow    object
# Flotation Column 01 Level       object
# Flotation Column 02 Level       object
# Flotation Column 03 Level       object
# Flotation Column 04 Level       object
# Flotation Column 05 Level       object
# Flotation Column 06 Level       object
# Flotation Column 07 Level       object
# % Iron Concentrate              object
# % Silica Concentrate            object
# dtype: object

# %%
for i in df.columns:
  df[i]=df[i].astype('float')

# %%
df.dtypes
# Out:
# % Iron Feed                     float64
# % Silica Feed                   float64
# Starch Flow                     float64
# Amina Flow                      float64
# Ore Pulp Flow                   float64
# Ore Pulp pH                     float64
# Ore Pulp Density                float64
# Flotation Column 01 Air Flow    float64
# Flotation Column 02 Air Flow    float64
# Flotation Column 03 Air Flow    float64
# Flotation Column 04 Air Flow    float64
# Flotation Column 05 Air Flow    float64
# Flotation Column 06 Air Flow    float64
# Flotation Column 07 Air Flow    float64
# Flotation Column 01 Level       float64
# Flotation Column 02 Level       float64
# Flotation Column 03 Level       float64
# Flotation Column 04 Level       float64
# Flotation Column 05 Level       float64
# Flotation Column 06 Level       float64
# Flotation Column 07 Level       float64
# % Iron Concentrate              float64
# % Silica Concentrate            float64
# dtype: object

# %%
df.describe()
# Out:
#          % Iron Feed  % Silica Feed    Starch Flow     Amina Flow  \
# count  736282.000000  736282.000000  736282.000000  736282.000000
# mean       56.298307      14.648984    2869.636615     488.165523
# std         5.160365       6.810741    1216.017896      91.254428
# min        42.740000       1.310000       0.002026     241.669000
# 25%        52.670000       8.940000    2075.070000     431.835848
# 50%        56.080000      13.850000    3020.230000     504.352500
# 75%        59.720000      19.600000    3728.930000     553.335750
# max        65.780000      33.400000    6300.230000     739.538000
#
#        Ore Pulp Flow    Ore Pulp pH  Ore Pulp Density  \
# count  736282.000000  736282.000000     736282.000000
# mean      397.570736       9.767315          1.680424
# std         9.705444       0.387176          0.069206
# min       376.249000       8.753340          1.519820
# 25%       394.248000       9.527050          1.647390
# ...

# %%
plt.figure(figsize=(10,8))
count=1

for i in df.columns:
  plt.subplot(4,6,count)
  sns.distplot(df[i])
  count+=1

# %%
plt.figure(figsize=(20,20))
count=1

for i in df.columns:
  plt.subplot(8,3,count)
  sns.histplot(df[i])
  count+=1

# %%
plt.figure(figsize=(20,20))
count=1

for i in df.columns:
  plt.subplot(8,3,count)
  sns.boxplot(df[i])
  count+=1

# %%
df.columns
# Out:
# Index(['% Iron Feed', '% Silica Feed', 'Starch Flow', 'Amina Flow',
#        'Ore Pulp Flow', 'Ore Pulp pH', 'Ore Pulp Density',
#        'Flotation Column 01 Air Flow', 'Flotation Column 02 Air Flow',
#        'Flotation Column 03 Air Flow', 'Flotation Column 04 Air Flow',
#        'Flotation Column 05 Air Flow', 'Flotation Column 06 Air Flow',
#        'Flotation Column 07 Air Flow', 'Flotation Column 01 Level',
#        'Flotation Column 02 Level', 'Flotation Column 03 Level',
#        'Flotation Column 04 Level', 'Flotation Column 05 Level',
#        'Flotation Column 06 Level', 'Flotation Column 07 Level',
#        '% Iron Concentrate', '% Silica Concentrate'],
#       dtype='object')

# %%
lis1=['% Iron Feed', '% Silica Feed', 'Starch Flow', 'Amina Flow',
       'Ore Pulp Flow', 'Ore Pulp pH', 'Ore Pulp Density',
       'Flotation Column 01 Air Flow', 'Flotation Column 02 Air Flow',
       'Flotation Column 03 Air Flow', 'Flotation Column 04 Air Flow',
       'Flotation Column 05 Air Flow', 'Flotation Column 06 Air Flow',
       'Flotation Column 07 Air Flow', 'Flotation Column 01 Level',
       'Flotation Column 02 Level', 'Flotation Column 03 Level',
       'Flotation Column 04 Level', 'Flotation Column 05 Level',
       'Flotation Column 06 Level', 'Flotation Column 07 Level',
       '% Iron Concentrate']

# %%
for i in lis1:
  Q1=df[i].quantile(0.25)
  Q2=df[i].quantile(0.50)
  Q3=df[i].quantile(0.75)
  IQR=Q3-Q1
  LF=Q1-1.5*IQR
  UF=Q3+1.5*IQR
  df=df[(df[i]<UF)&(df[i]>LF)]

# %%
plt.figure(figsize=(20,20))
count=1

for i in df.columns:
  plt.subplot(8,3,count)
  sns.boxplot(df[i])
  count+=1

# %%
plt.figure(figsize=(20,20))
count=1

for i in df.columns:
  plt.subplot(8,3,count)
  sns.scatterplot(df[i],df['% Silica Concentrate'])
  count+=1

# %%
plt.figure(figsize=(30,30))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
X=df.drop('% Silica Concentrate',axis=1).values
X
# Out:
# array([[  55.2  ,   16.98 , 3019.53 , ...,  446.37 ,  523.344,   66.91 ],
#        [  55.2  ,   16.98 , 3024.41 , ...,  445.922,  498.075,   66.91 ],
#        [  55.2  ,   16.98 , 3043.46 , ...,  447.826,  458.567,   66.91 ],
#        ...,
#        [  49.75 ,   23.2  , 2692.2  , ...,  336.035,  433.13 ,   64.27 ],
#        [  49.75 ,   23.2  , 1164.12 , ...,  340.844,  433.966,   64.27 ],
#        [  49.75 ,   23.2  , 1164.12 , ...,  374.354,  441.182,   64.27 ]])

# %%
y=df['% Silica Concentrate'].values
y
# Out:
# array([1.31, 1.31, 1.31, ..., 1.71, 1.71, 1.71])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
from tensorflow.keras import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
ann=Sequential()

# %%
ann.add(Dense(units=20,activation='relu'))

# %%
ann.add(Dense(units=20,activation='relu'))

# %%
ann.add(Dense(units=1))

# %%
ann.compile(optimizer='adam',loss='mse',metrics=['mae'])

# %%
ann.fit(X_train,y_train,epochs=300,validation_data=(X_test, y_test),verbose=2,batch_size=70,callbacks=[early_stop])
# Out:
# Epoch 1/300
# 5610/5610 - 12s - loss: 0.3490 - mae: 0.4295 - val_loss: 0.2783 - val_mae: 0.3915 - 12s/epoch - 2ms/step
# Epoch 2/300
# 5610/5610 - 12s - loss: 0.2657 - mae: 0.3776 - val_loss: 0.2566 - val_mae: 0.3706 - 12s/epoch - 2ms/step
# Epoch 3/300
# 5610/5610 - 12s - loss: 0.2520 - mae: 0.3670 - val_loss: 0.2477 - val_mae: 0.3619 - 12s/epoch - 2ms/step
# Epoch 4/300
# 5610/5610 - 11s - loss: 0.2435 - mae: 0.3597 - val_loss: 0.2418 - val_mae: 0.3591 - 11s/epoch - 2ms/step
# Epoch 5/300
# 5610/5610 - 10s - loss: 0.2381 - mae: 0.3553 - val_loss: 0.2370 - val_mae: 0.3575 - 10s/epoch - 2ms/step
# Epoch 6/300
# 5610/5610 - 11s - loss: 0.2340 - mae: 0.3525 - val_loss: 0.2349 - val_mae: 0.3532 - 11s/epoch - 2ms/step
# Epoch 7/300
# 5610/5610 - 13s - loss: 0.2303 - mae: 0.3499 - val_loss: 0.2302 - val_mae: 0.3499 - 13s/epoch - 2ms/step
# Epoch 8/300
# 5610/5610 - 12s - loss: 0.2277 - mae: 0.3478 - val_loss: 0.2271 - val_mae: 0.3463 - 12s/epoch - 2ms/step
# Epoch 9/300
# ...
